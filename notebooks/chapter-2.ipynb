# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### #1 page 50 - sinsum

# %%
L = 0.5
x = np.linspace(-0.5, 0.5)
y = np.sign(x)

# %%
plt.plot(x, y)

# %%
def sinsum(x, k):
    out = np.zeros(len(x))
    for n in range(1, k, 2):
        out += 4 * np.sin(2 * np.pi * n * x) / (np.pi * n)
    return out

# %%
plt.plot(x, sinsum(x, 2))

# %%
plt.plot(x, sinsum(x, 10))

# %%
plt.plot(x, sinsum(x, 100))

# %% [markdown]
# #### #2

# %%
t = 2*x[-1]
t
# Out:
# 1.0
